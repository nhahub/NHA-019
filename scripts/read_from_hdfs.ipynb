# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("ReadParquetFromHDFS3").getOrCreate()

df = spark.read.parquet("hdfs://namenode:9000/user/smart_farming_data/*.parquet")

df.show(20, truncate=False)  # Show only first 20 rows
print("Total rows:", df.count())
# Out:
# +------------------------------------+-------------------+-------------+-------+-----------+--------+--------+------------------+------------------+-------+----------+---------+
# |sensor_id                           |timestamp          |soil_moisture|soil_pH|temperature|rainfall|humidity|sunlight_intensity|pesticide_usage_ml|farm_id|region    |crop_type|
# +------------------------------------+-------------------+-------------+-------+-----------+--------+--------+------------------+------------------+-------+----------+---------+
# |76f8d565-a0de-501c-8c26-2921c989aa8d|2024-01-01T01:00:00|39.44        |5.82   |21.54      |0.0     |56.61   |0.0               |13.28             |farm_1 |NileDelta |Wheat    |
# |8386c803-2e1f-5d24-9114-43c31ef4a50b|2024-01-01T01:00:00|33.33        |6.53   |23.89      |0.0     |49.37   |0.0               |6.52              |farm_2 |NileDelta |Rice     |
# ...
